# %% [markdown]
# # Leer archivo .parquet de errores

# %%
# logicData_etl/utils/read_quarantine_errors_pyarrow.py
import argparse
import pandas as pd

# %%
def main():
    parser = argparse.ArgumentParser()
    parser.add_argument('--path', required=False, help='s3://bucket/... or local file/folder')
    ns = parser.parse_args()
    path = ns.path

    if path.startswith("s3://"):
        # requiere s3fs instalado y credenciales AWS configuradas
        df = pd.read_parquet(path, engine="pyarrow", storage_options={})
    else:
        df = pd.read_parquet(path, engine="pyarrow")

    print("shape:", df.shape)
    print(df.head(50))

# %%
if __name__ == "__main__":
    main()

# %%
#python logicData_etl/utils/read_quarantine_errors_pyarrow.py --path s3://mi-bucket/catalogo_errors/

# %% [markdown]
# ## Ejecutar

# %%
import sys
# Reemplaza por tu ruta real
sys.argv = ['notebook', '--path', 's3://mi-bucket/catalogo_errors/']

# %%
import sys
# Reemplaza por tu ruta real
sys.argv = ['notebook', '--path',r'C:\Users\john0\Downloads\part-00000-596b6617-7577-4134-af83-711eabe26291-c000.snappy.parquet']

# %%
path=r"C:\Users\john0\Downloads\part-00000-85eb4395-d88c-4817-b544-6a68287036a1-c000.snappy.parquet"
df = pd.read_parquet(path, engine="pyarrow")

# %%
df.head()
# Out:
#   id_producto     categoria  precio tipo_entrega               processed_at  \
# 0       P0004          Ropa  185.31     Next Day 2026-04-20 03:22:05.043516
# 1       P0006  Electrónicos  346.75     Same Day 2026-04-20 03:22:05.043516
# 2       P0007          Ropa   24.46     Next Day 2026-04-20 03:22:05.043516
# 3       P0009  Medicamentos  315.81   Programada 2026-04-20 03:22:05.043516
# 4       P0010   Perecederos   45.47     Same Day 2026-04-20 03:22:05.043516
#
#                  fecha_carga
# 0 2026-04-20 03:22:50.266446
# 1 2026-04-20 03:22:50.266446
# 2 2026-04-20 03:22:50.266446
# 3 2026-04-20 03:22:50.266446
# 4 2026-04-20 03:22:50.266446

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_producto   200 non-null    str
#  1   categoria     200 non-null    str
#  2   precio        200 non-null    str
#  3   tipo_entrega  200 non-null    str
#  4   processed_at  200 non-null    datetime64[ns]
#  5   fecha_carga   200 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), str(4)
# memory usage: 14.9 KB
